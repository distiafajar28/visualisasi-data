# %% [markdown]
# <a href="https://colab.research.google.com/github/distiafajar28/visualisasi-data/blob/main/Praktikum_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM BAR CHART**

# %% [markdown]
# Kelompok 12:
# - Distia Fajar Familiati 0110222163
# - Sabrina Ramadhani 0110222068
# - Muhammad Faris Zacky 0110222227

# %%
import matplotlib.pyplot as plt

jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

plt.bar(jurusan, jumlah_mahasiswa, color=['red', 'blue', 'purple', 'orange'])
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Jumlah Mahasiswa per Jurusan')
plt.show()

# %% [markdown]
# **a. Basic Bar Chart Dengan Matplotlib**

# %%
import matplotlib.pyplot as plt

jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

plt.bar(jurusan, jumlah_mahasiswa, color=['red', 'blue', 'purple', 'orange'])
plt.title('Jumlah Mahasiswa per Jurusan')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Kustomanisasi Bar Chart**

# %%
import matplotlib.pyplot as plt

jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

plt.bar(jurusan, jumlah_mahasiswa, color=['red', 'blue', 'purple', 'orange'])
plt.title('Jumlah Mahasiswa per Jurusan')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)

for i, v in enumerate(jumlah_mahasiswa):
    print(f"Index ke-{i}, jumlah: {v}")

plt.show()
# Out:
# Index ke-0, jumlah: 120
# Index ke-1, jumlah: 150
# Index ke-2, jumlah: 100
# Index ke-3, jumlah: 80

# %% [markdown]
# **Multiple Bar Chart**

# %%
import matplotlib.pyplot as plt

jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]
jumlah_mahasiswa_2024 = [110, 140, 95, 85]

x = range(len(jurusan))
width = 0.4

plt.bar(x, jumlah_mahasiswa, width, label='2023', color='pink')
plt.bar([p + width for p in x], jumlah_mahasiswa_2024, width=width, label='2024', color='skyblue')

plt.title('Jumlah Mahasiswa per Jurusan (2023 vs 2024)')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=45)
plt.xticks([p + width/2 for p in x], jurusan)
plt.legend()

plt.show()

# %% [markdown]
# **d. Basic Bar Chart untuk Melihat Pola dan Tren**

# %%
import matplotlib.pyplot as plt

jurusan = ['Ilmu Komputer', 'Teknik Informatika', 'Sistem Informasi', 'Data Science']
tahun = ['2019', '2020', '2021', '2022', '2023']
data = {
    'Ilmu Komputer': [100, 110, 120, 130, 140],
    'Teknik Informatika': [120, 120, 132, 145, 160],
    'Sistem Informasi': [90, 95, 100, 105, 110],
    'Data Science': [70, 75, 80, 85, 90]
}
width = 0.2
x = range(len(tahun))

plt.bar(x, data['Ilmu Komputer'], width=width, label='Ilmu Komputer', color='pink')
plt.bar([p + width for p in x],
        data['Sistem Informasi'], width=width, label='Sistem Informasi', color='red')
plt.bar([p + width * 2 for p in x],
        data['Teknik Informatika'], width=width, label='Teknik Informatika', color='skyblue')
plt.bar([p + width * 3 for p in x],
        data['Data Science'], width=width, label='Data Science', color='orange')

plt.title('Tren Jumlah Mahasiswa per Jurusan ( 2019 - 2023)')

plt.xlabel('Tahun')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks([p + width for p in x], tahun)
plt.legend()

plt.show()
